# %%
import pandas as pd
import numpy as np
df=pd.read_excel("/content/solar_energy_usage_indian_states.xlsx")
df.head()
# Out:
#                State  Average Solar Radiation (kWh/m²/day)  \
# 0     Andhra Pradesh                                  6.24
# 1  Arunachal Pradesh                                  4.56
# 2              Assam                                  4.86
# 3              Bihar                                  6.29
# 4       Chhattisgarh                                  5.20
#
#    Installed Solar Capacity (MW)  Predicted Usage (GWh/year)  \
# 0                           5781                       11751
# 1                           5366                        7826
# 2                           4604                        5764
# 3                            852                       25802
# 4                           9036                        7509
#
#    Population (Millions)
# 0                   82.3
# 1                  104.8
# 2                   51.6
# 3                  161.2
# 4                   96.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   State                                 30 non-null     object
#  1   Average Solar Radiation (kWh/m²/day)  30 non-null     float64
#  2   Installed Solar Capacity (MW)         30 non-null     int64
#  3   Predicted Usage (GWh/year)            30 non-null     int64
#  4   Population (Millions)                 30 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.3+ KB

# %%
df.describe()
# Out:
#        Average Solar Radiation (kWh/m²/day)  Installed Solar Capacity (MW)  \
# count                             30.000000                      30.000000
# mean                               5.351333                    5229.400000
# std                                0.688044                    2816.639556
# min                                4.030000                     852.000000
# 25%                                4.972500                    2692.500000
# 50%                                5.325000                    5432.000000
# 75%                                5.905000                    7777.500000
# max                                6.480000                    9554.000000
#
#        Predicted Usage (GWh/year)  Population (Millions)
# count                   30.000000              30.000000
# mean                 23259.900000             108.050000
# std                  13174.231987              60.753713
# min                   3948.000000               4.000000
# 25%                  10894.500000              52.225000
# 50%                  25098.000000             108.000000
# 75%                  34077.250000             160.200000
# max                  46765.000000             198.800000

# %%
df['State'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'Delhi', 'Jammu and Kashmir'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['State'] = label_encoder.fit_transform(df['State'])

# %%
df.head()
# Out:
#    State  Average Solar Radiation (kWh/m²/day)  Installed Solar Capacity (MW)  \
# 0      0                                  6.24                           5781
# 1      1                                  4.56                           5366
# 2      2                                  4.86                           4604
# 3      3                                  6.29                            852
# 4      4                                  5.20                           9036
#
#    Predicted Usage (GWh/year)  Population (Millions)
# 0                       11751                   82.3
# 1                        7826                  104.8
# 2                        5764                   51.6
# 3                       25802                  161.2
# 4                        7509                   96.1

# %%
df["Predicted Usage (GWh/year)"].sum()
# Out:
# np.int64(697797)

# %%
df["Predicted Usage (GWh/year)"].mean()
# Out:
# np.float64(23259.9)

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns=["Predicted Usage (GWh/year)"])
y = df["Predicted Usage (GWh/year)"]

# %%
x
# Out:
#     State  Average Solar Radiation (kWh/m²/day)  \
# 0       0                                  6.24
# 1       1                                  4.56
# 2       2                                  4.86
# 3       3                                  6.29
# 4       4                                  5.20
# 5       6                                  5.69
# 6       7                                  4.11
# 7       8                                  4.60
# 8       9                                  4.61
# 9      11                                  5.37
# 10     12                                  5.70
# 11     13                                  6.19
# 12     14                                  5.77
# 13     15                                  5.28
# 14     16                                  6.22
# 15     17                                  4.96
# 16     18                                  5.22
# 17     19                                  5.95
# 18     20                                  6.48
# 19     21                                  6.18
# 20     22                                  5.11
# 21     23                                  4.03
# 22     24                                  5.66
# 23     25                                  5.01
# 24     26                                  5.96
# 25     27                                  5.38
# 26     28                                  5.46
# 27     29                                  5.13
# 28      5                                  5.27
# 29     10                                  4.05
#
#     Installed Solar Capacity (MW)  Population (Millions)
# 0                            5781                   82.3
# 1                            5366                  104.8
# 2                            4604                   51.6
# 3                             852                  161.2
# 4                            9036                   96.1
# 5                            5019                  189.2
# 6                            8126                   54.1
# 7                            1432                   36.9
# 8                            9554                   43.2
# 9                            9104                   23.3
# 10                           5498                  156.1
# 11                           1384                    4.0
# 12                           1874                  180.2
# 13                           7857                  104.2
# 14                           1312                  198.8
# 15                           7076                  124.4
# 16                           2105                  160.5
# 17                           9155                  111.2
# 18                           3122                  151.1
# 19                           5599                  186.6
# 20                           4311                  159.3
# 21                           2757                  118.0
# 22                           8099                   32.4
# 23                           2671                   25.8
# 24                           8974                   94.0
# 25                           2920                   34.9
# 26                           7539                  186.9
# 27                           6214                  117.2
# 28                           2558                  193.2
# 29                           6983                   60.0

# %%
y
# Out:
# 0     11751
# 1      7826
# 2      5764
# 3     25802
# 4      7509
# 5     13440
# 6     21472
# 7     12749
# 8     36123
# 9     21941
# 10    33721
# 11     4920
# 12    34196
# 13    10609
# 14    25384
# 15    35335
# 16    35274
# 17    29181
# 18    33323
# 19    30584
# 20    24812
# 21    10358
# 22    40238
# 23    33283
# 24    12472
# 25    35262
# 26     3948
# 27    46765
# 28    46177
# 29     7578
# Name: Predicted Usage (GWh/year), dtype: int64

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(ytest, ypred)
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)

# Print results
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared Score:", r2)
# Out:
# Mean Absolute Error: 17388.232998732765
# Mean Squared Error: 346159348.94205123
# R-squared Score: -5.143437713683995
